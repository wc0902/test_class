# %%
print("hello world")
# Out:
# hello world

# %%
##Python數學運算
print("這是我的第1個函式") #str
print('這是我的第2個函式') # str
print(50) #int
print(50.0) #float
# Out:
# 這是我的第1個函式
# 這是我的第2個函式
# 50
# 50.0

# %%
print("這是整數", 50)
print("這是浮點數", 50.5)
print("這是字串", 'robert')
print("這是布林值", True)
print("這是布林值", False)
# Out:
# 這是整數 50
# 這是浮點數 50.5
# 這是字串 robert
# 這是布林值 True
# 這是布林值 False
